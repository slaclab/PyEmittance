# %%
from pyemittance.emittance_calc import EmitCalc
from pyemittance.emit_eval_example import eval_emit_surrogate, eval_emit_machine
import numpy as np

# %%
def get_bs_model(*args):
    return np.random.normal(1e-6, 5e-5), np.random.normal(1e-6, 5e-6), 0, 0

# %%
eval_emit_surrogate(
    get_bs_model,
    init_config = None,
    quad_init=[-6, -4, -2, 0],
    config_name='sim',
    config_dict=None,
    adapt_ranges=True,
    num_points=7,
    check_sym=True,
    infl_check=True,
    add_pnts=True,
    show_plots=True,
    add_noise=False,
    use_prev_meas=False,
    quad_tol=0.05,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# No configuration specified. Taking default LCLS-OTR2 configs.
# Savepaths not set. Please set them in 'configs/savepaths.json'
# Using examples directory:  /Users/smiskov/Documents/SLAC/PyEmittance/examples
# {'nemitx': nan,
#  'nemity': nan,
#  'nemitx_err': nan,
#  'nemity_err': nan,
#  'nemit': None,
#  'nemit_err': None,
#  'bmagx': nan,
#  'bmagy': nan,
#  'bmagx_err': nan,
#  'bmagy_err': nan,
#  'bmag_emit': None,
#  'bmag_emit_err': None,
#  'opt_q_x': None,
#  'opt_q_y': None,
#  'total_points_measured': 32,
#  'quadvalsx': [-1.9999999999999998,
#   -1.6666666666666663,
#   -1.3333333333333328,
#   -1.1666666666666663,
#   -0.9999999999999999,
#   -0.8333333333333335,
#   -0.5000000000000004],
#  'beamsizesx': [0.00012199685441379518,
#   4.42640653865549e-05,
#   2.150401701317685e-06,
#   3.856611246254216e-05,
#   1.494215549419128e-05,
#   3.871365517760462e-05,
#   -2.900012878184103e-05],
#  'beamsizeserrx': [1.8299528162069276e-06,
#   6.639609807983235e-07,
#   3.2256025519765277e-08,
#   5.784916869381324e-07,
#   2.2413233241286921e-07,
#   5.807048276640693e-07,
#   -4.350019317276154e-07],
#  'quadvalsy': [-0.9999999999999999,
#   -0.6666666666666664,
#   -0.3333333333333331,
#   -0.16666666666666655,
#   0.0,
#   0.16666666666666657,
#   0.4999999999999996],
#  'beamsizesy': [2.610691880746143e-06,
#   6.925317603460974e-06,
#   3.486712094043408e-07,
#   1.3976258070119006e-05,
#   2.7246497300770045e-06,
#   8.479206620569701e-08,
#   5.922840716031992e-06],
#  'beamsizeserry': [3.9160378211192144e-08,
#   1.038797640519146e-07,
#   5.230068141065112e-09,
#   2.0964387105178508e-07,
#   4.0869745951155064e-08,
#   1.271880993085455e-09,
#   8.884261074047987e-08]}

# %%
eval_emit_machine(
    inj_config=None,
    quad_init=[-6, -4, -2, 0],
    online=False,
    config_name='FACET_nominal',
    config_dict=None,
    meas_type='OTRS',
    adapt_ranges=True,
    num_points=7,
    check_sym=True,
    infl_check=True,
    add_pnts=True,
    show_plots=True,
    use_prev_meas=True,
    quad_tol=0.05,
    save_runs=False,
    calc_bmag=True,
)
# Out:
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Running offline.
# Savepaths not set. Please set them in 'configs/savepaths.json'
# Using examples directory:  /Users/smiskov/Documents/SLAC/PyEmittance/examples
# {'nemitx': 3.902079791539191e-06,
#  'nemity': 4.6450422005879046e-07,
#  'nemitx_err': 4.8512478845316354e-08,
#  'nemity_err': 2.763220072309158e-08,
#  'nemit': 1.3463032831335143e-06,
#  'nemit_err': 8.181858910049366e-08,
#  'bmagx': 3.39412058282883,
#  'bmagy': 4.443324916593874,
#  'bmagx_err': 0.04219729195125346,
#  'bmagy_err': 0.2643223477231196,
#  'bmag_emit': 5.228300904739272e-06,
#  'bmag_emit_err': 4.493499043232628e-07,
#  'opt_q_x': -7.1257410936671715,
#  'opt_q_y': 2.0000000000000004,
#  'total_points_measured': 23,
#  'quadvalsx': [-6.562870546833587,
#   -6.750494062444782,
#   -6.9381175780559765,
#   -7.031929335861574,
#   -7.1257410936671715,
#   -7.219552851472769,
#   -6.964920937429004],
#  'beamsizesx': [0.00022621703775435134,
#   0.00013930514555892258,
#   5.1514673175586904e-05,
#   6.34239394682012e-05,
#   0.0001317576932189887,
#   0.00032043510597706246,
#   5.1514673175586904e-05],
#  'beamsizeserrx': [3.39325556631527e-06,
#   2.0895771833838387e-06,
#   7.727200976338035e-07,
#   9.513590920230179e-07,
#   1.9763653982848304e-06,
#   4.806526589655937e-06,
#   7.727200976338035e-07],
#  'quadvalsy': [0.8571428571428573,
#   2.0000000000000004,
#   3.1428571428571432,
#   3.714285714285715,
#   4.2857142857142865,
#   4.857142857142858,
#   6.000000000000002],
#  'beamsizesy': [0.00014227900067715268,
#   0.000594897046187817,
#   0.0001119713226559634,
#   0.00023430037368117455,
#   0.0002209350920030388,
#   0.0005946509250372332,
#   0.00014581407788953057],
#  'beamsizeserry': [2.13418501015729e-06,
#   8.923455692817254e-06,
#   1.679569839839451e-06,
#   3.514505605217618e-06,
#   3.3140263800455817e-06,
#   8.919763875558497e-06,
#   2.1872111683429584e-06]}
